# %% [markdown]
# # Markdown in Jupyter Notebook

# %% [markdown]
# <b> Author: </b> Som | som@e2eSolutionArchitect.com | [e2eSolutionArchitect.com](http://e2esolutionarchitect.com) <br>
# <b> Version: </b> Python 3, Jupyter Notebook version 6.0.3 <br>
# Watch <b>e2e Solution Architect</b> tutorials. [click here](https://www.youtube.com/channel/UC5Juuk7aTvbRmrABMq4onJA/videos) <br>
# [GitHub link](https://github.com/e2eSolutionArchitect/datascience/blob/main/python/Markdown%20in%20Jupyter%20Notebook.ipynb)

# %% [markdown]
# ## Agenda

# %% [markdown]
# 1. Jupyter notebook menus
# 2. What is Markdown?
# 3. How to Markdown a cell?
# 4. Heading
# 5. Line break
# 6. Bold or Emphasise
# 7. Font Color
# 8. Insert Image
# 9. Underline and Italic
# 10. Create Link
# 11. Quote
# 12. Horizontal line
# 13. Bullet
# 14. Numbered list
# 15. Code or syntax highlight
# 16. Mathematical symbols
# 17. Insert youtube video

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/jy0R3V5LRHc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py:701: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe width="560" height="315" src="https://www.youtube.com/embed/jy0R3V5LRHc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Use <b>Shift+Enter</b> in your keyboard or click the Run button in menus to execute a cell.

# %% [markdown]
# # Prerequisite: Know the Menus

# %% [markdown]
# ![jupyter-notebook-menus.png](attachment:jupyter-notebook-menus.png)

# %% [markdown]
# # What is Markdown?

# %% [markdown]
# Markdown is a lightweight and popular Markup language which is often converted into the corresponding HTML

# %% [markdown]
# ## How to Markdown a cell?

# %% [markdown]
# ![markdown.png](attachment:markdown.png) <br> <b>Image 1.0</b>

# %% [markdown]
# Check the top menu bar. Click the drop down as shown above . Refer Image 1.0 . Select <b>'Markdown'</b> option. and Use <b>Shift+Enter</b> in your keyboard to execute the cell.

# %% [markdown]
# # Headings or Labels

# %%
# Level 1 heading
## Level 2 heading
### Level 3 or Sub Heading
#### Level 4 or Section Heading

#### Change the cell type to 'Markdown' and run the cell 'Shift' + 'Enter'

# %% [markdown]
# # Level 1 heading
# ## Level 2 heading
# ### Level 3 or Sub Heading
# #### Level 4 or Section Heading

# %% [markdown]
# # Line Break

# %%
# First line. <br> Next line

# %% [markdown]
# First line. <br> Next line

# %% [markdown]
# # Bold or Emphasise

# %%
# Option 1: Make it <b> Bold </b> text.
# Option 2: Make it __Bold__ text.
# Option 3: Make it **Bold** text.

#### Change the cell type to 'Markdown' and run the cell 'Shift' + 'Enter'

# %% [markdown]
# Make it <b> Bold </b> text. <br>
# Make it __Bold__ text.<br>
# Make it **Bold** text.

# %% [markdown]
# # Font Color

# %%
# Write it in <font color=red> RED</font>
# Write it in <font color=red|blue|green|yellow> RED</font>

# %% [markdown]
# Write it in <font color=red> RED</font>

# %% [markdown]
# # Insert Image

# %%
# Drag and drop the image in a Markdown cell
# ![mathematical-symbols-jupyter-notebook.png](attachment:mathematical-symbols-jupyter-notebook.png)

# %% [markdown]
# ![mathematical-symbols-jupyter-notebook.png](attachment:mathematical-symbols-jupyter-notebook.png)

# %% [markdown]
# # Underline and Italic

# %%
# Option 1: Make it <i> <u> Italic </u> </i> text.
# Option 2: Make it _Italic_ text.
# Option 3: Make it *Italic* text.

#### Change the cell type to 'Markdown' and run the cell 'Shift' + 'Enter'

# %% [markdown]
# Make it <i> <u>Italic</u> </i> text. <br>
# Make it _Italic_ text. <br>
# Make it *Italic* text.

# %% [markdown]
# ### Attention: You might have already noticed the usages of HTML tags. It is because Markdown is also a markup language.

# %% [markdown]
# # Link

# %%
# [Link Text](https://www.youtube.com/channel/UC5Juuk7aTvbRmrABMq4onJA/videos "Title")
# [Click here for end to end Solution Architect Tutorials ](https://www.youtube.com/channel/UC5Juuk7aTvbRmrABMq4onJA/videos "e2e Solution Architect")

# %% [markdown]
# [Click here for end to end Solution Architect Tutorials ](https://www.youtube.com/channel/UC5Juuk7aTvbRmrABMq4onJA/videos "e2e Solution Architect")

# %% [markdown]
# # Quote

# %%
# use > to quote 
# > Quote it <br>
# > quote this line too

# %% [markdown]
# > Quote it <br>
# > quote this line too

# %% [markdown]
# # Horizontal line

# %%
# ---
# <p>Hey there!</p>
# give a new empty line here

# ---
# Regards <br>
# Som

# %% [markdown]
# ---
# <p>Hey there! </p>
# give a new empty line here
#
# ---
# Regards <br>
# Som

# %% [markdown]
# # Bullet

# %%
# * Bullet 1
# * Bullet 2
#    * Sub Bullet 2.1 # indent with single tab 
#    * Sub Bullet 2.2
#        * Sub Bullet 2.2.1 # indent with tab

# %% [markdown]
# * Bullet 1
# * Bullet 2
#     * Sub Bullet 2.1
#     * Sub Bullet 2.2
#         * Sub Bullet 2.2.1

# %% [markdown]
# # Numbered List

# %%
# Start each line with 1.<give space> It will automatically order line numbers
# for sub line, indent with tab and again start with 1. <give space>
# 1. Line 1
# 1. Line 2
# 1. Line 3
#    1. Line
#    1. New Line

# %% [markdown]
# 1. Line 1
# 1. Line 2
# 1. Line 3
#     1. Line
#     1. New level
#         1. New level2
#             1. New level3

# %% [markdown]
# # Code or Syntax highlight

# %%
# ```python
# def checkOut(e2eTutorials)
#  if not checked:
#    return checked
# ```

# %% [markdown]
# ```python
# def checkOut(e2eTutorials)
#   if not checked:
#     return checked
# ```

# %% [markdown]
# # Mathematical Symbols

# %%
# $ : All the Math you want to write in the markdown should be inside opening and closing $ symbol in order to be processed as Math.

# %%
# $\sqrt{(7)^2 + (2+8)^4}$

# %% [markdown]
# $\sqrt{(7)^2 + (2+8)^4}$

# %%
# this great source info for Mathematical Symbol has been referred https://medium.com/analytics-vidhya/writing-math-equations-in-jupyter-notebook-a-naive-introduction-a5ce87b9a214 

# Hat: \hat
# Subscript: _{}
# Sum: \sum
# Limits of sum: \limits _{} ^{}
# Beta: \beta

# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $

# %% [markdown]
# $\hat{Y} = \hat{\beta}_{0} + \sum \limits _{j=1} ^{p} X_{j}\hat{\beta}_{j} $

# %%
# \beta : Creates the symbol beta
# \hat{} : A hat is covered over anything inside the curly braces of \hat{}. E.g. in \hat{Y} hat is created over Y and in \hat{\beta}_{0},  hat is shown over beta
# _{} : Creates as subscript, anything inside the curly braces after _. E.g. \hat{\beta}_{0} will create beta with a hat and give it a subscript of 0.
# ^{} : (Similar to subscript) Creates as superscript, anything inside the curly braces after ^.
# \sum : Creates the summation symbol
# \limits _{} ^{} : Creates lower and upper limit for the \sum using the subscript and superscript notation.

# *** : Creates horizontal line
# &emsp; : Creates space. (Ref: Space in ‘markdown’ cell of Jupyter Notebook)
# \gamma : Creates gamma symbol
# \displaystyle : Forces display mode (BONUS 3 above). (Ref: Display style in Math mode)
# \frac{}{} : Creates fraction with two curly braces from numerator and denominator.
# <br> : Creates line breaks
# \Bigg : Helps create parenthesis of big sizes. (Ref: Brackets and Parentheses)
# \partial : Creates partial derivatives symbol
# \underset() : To write under a text. E.g. gamma under arg min, instead of a subscript. In the algorithm you’ll see both types.
# \in : Creates belongs to symbol which is heavily used in set theory.

# %% [markdown]
# ***
# $\mathbf{\text{Gradient Tree Boosting Algorithm}}$<br>
# ***
# 1.&emsp;Initialize model with a constant value $$f_{0}(x) = \textrm{arg min}_{\gamma} \sum \limits _{i=1} ^{N} L(y_{i}, \gamma)$$
# 2.&emsp;For m = 1 to M:<br>
# &emsp;&emsp;(a)&emsp;For $i = 1,2,...,N$ compute<br>
#     $$r_{im} = - \displaystyle \Bigg[\frac{\partial L(y_{i}, f(x_{i}))}{\partial f(x_{i})}\Bigg]_{f=f_{m−1}}$$
# &emsp;&emsp;(b)&emsp;Fit a regression tree to the targets $r_{im}$ giving terminal regions<br>
# &emsp;&emsp;&emsp;&emsp;$R_{jm}, j = 1, 2, . . . , J_{m}.$<br><br>
# &emsp;&emsp;(c)&emsp;For $j = 1, 2, . . . , J_{m}$ compute<br>
# $$\gamma_{jm} = \underset{\gamma}{\textrm{arg min}} \sum \limits _{x_{i} \in R_{jm}} L(y_{i}, f_{m−1}(x_{i}) + \gamma)$$
# <br>
# &emsp;&emsp;(d)&emsp;Update $f_{m}(x) = f_{m−1}(x) + \sum _{j=1} ^{J_{m}} \gamma_{jm} I(x \in R_{jm})$<br><br>
# 3. Output $\hat{f}(x) = f_{M}(x)$
# ***

# %%
# Variance Covariance Matrix in Markdown
# $\Large \Sigma = \begin{bmatrix} \sigma^{2}_{xx} & \sigma_{xy} \\ \sigma_{yx} & \sigma^{2}_{yy} \end{bmatrix}$

# %% [markdown]
# $\Large \Sigma = \begin{bmatrix} \sigma^{2}_{xx} & \sigma_{xy} \\ \sigma_{yx} & \sigma^{2}_{yy} \end{bmatrix}$

# %% [markdown]
# ### Few awesome examples of LaTeX

# %%
# Please refer https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd for example

# To add little spacing in math mode use \,
# To add a new line when in math mode use \\
# To display fraction use \frac{arg 1}{arg 2}
# For power (superscripts text) use ^{}
# For indices (subscripts) use _{}
# For roots use \sqrt[n]{arg}
# The [n]is optional.

# %%
# $ e^{i \pi} + 1 = 0 $

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/8bc71d28b957af66396dc263cc1e6b22/raw/67356a84f02677937666856866e61d35a87f19c8/introLatex.tex)

# %% [markdown]
# $ e^{i \pi} + 1 = 0 $

# %%
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}	
# $$

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/0ffd3fdfb98edc5d86d6f2b0e5cbf4a5/raw/135f15576a61f1702fedf130e49318a4b8d2c805/Note1.tex)

# %% [markdown]
# $$
# \frac{arg 1}{arg 2} \\
# x^2\\
# e^{i\pi}\\
# A_i\\
# B_{ij}\\
# \sqrt[n]{arg}
# $$

# %%
# Greek Letters <br>
# Given : $\pi = 3.14$ , $\alpha = \frac{3\pi}{4}\, rad$
# $$
# \omega = 2\pi f \\
# f = \frac{c}{\lambda}\\
# \lambda_0=\theta^2+\delta\\
# \Delta\lambda = \frac{1}{\lambda^2}
# $$

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/54c66e7d4cd30133f32fd53b24f17128/raw/2bba61fb1902ec3e8e70daf027054aa7c9c447d3/greek.tex)

# %% [markdown]
# <b>Greek Letters</b> <br>
# Given : $\pi = 3.14$ , $\alpha = \frac{3\pi}{4}\, rad$
# $$
# \omega = 2\pi f \\
# f = \frac{c}{\lambda}\\
# \lambda_0=\theta^2+\delta\\
# \Delta\lambda = \frac{1}{\lambda^2}
# $$

# %%
# <b> Roman Names </b>
# $$
# \sin(-\alpha)=-\sin(\alpha)\\
# \arccos(x)=\arcsin(u)\\
# \log_n(n)=1\\
# \tan(x) = \frac{\sin(x)}{\cos(x)}
# $$

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/df8997c758e7bc677c32fbc635bf882a/raw/b6b0f3602cbce0b8c79d625545d405b9e41d2809/roman.tex)

# %% [markdown]
# <b> Roman Names </b>
# $$
# \sin(-\alpha)=-\sin(\alpha)\\
# \arccos(x)=\arcsin(u)\\
# \log_n(n)=1\\
# \tan(x) = \frac{\sin(x)}{\cos(x)}
# $$

# %%
# limit
# Limit at plus infinity	: $$\lim_{x \to +\infty} f(x)$$ 
# Limit at minus infinity	: $$\lim_{x \to -\infty} f(x)$$	
# Limit at $\alpha$  : $$\lim_{x \to \alpha} f(x)$$

# Max : $$\max_{x \in [a,b]}f(x)$$	
# Min : $$\min_{x \in [\alpha,\beta]}f(x)$$	
# Sup : $$\sup_{x \in \mathbb{R}}f(x)$$	
# Inf : $$\inf_{x > s}f(x)$$

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/0b7234bc6205f83893ee4bd598c72048/raw/a40c69a5fd8cd9291c3c198794ef3f09677f820b/limit.tex)

# %% [markdown]
# <b>limit</b>
# Limit at plus infinity	: $$\lim_{x \to +\infty} f(x)$$
# Limit at minus infinity	: $$\lim_{x \to -\infty} f(x)$$
# Limit at $\alpha$  : $$\lim_{x \to \alpha} f(x)$$
#
# Max : $$\max_{x \in [a,b]}f(x)$$
# Min : $$\min_{x \in [\alpha,\beta]}f(x)$$
# Sup : $$\sup_{x \in \mathbb{R}}f(x)$$
# Inf : $$\inf_{x > s}f(x)$$

# %%
# Sum from 0 to +inf:

# $$\sum_{j=0}^{+\infty} A_{j}$$

# Double sum:
# $$\sum^k_{i=1}\sum^{l+1}_{j=1}\,A_i A_j$$	


# Taylor expansion of $e^x$:
#  $$ e^x  = \sum_{k=0}^{n}\, \frac{x^k}{k!} + o(x^n) $$

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/e89542ad298654c42f6d4868b561ea8d/raw/29e0be04892809b01340410b7d0ff12dd8d1b551/sum.tex)

# %% [markdown]
# <b> Sum from 0 to +inf: </b>
#
# $$\sum_{j=0}^{+\infty} A_{j}$$
#
# <b> Double sum:</b>
# $$\sum^k_{i=1}\sum^{l+1}_{j=1}\,A_i A_j$$
#
#
# <b> Taylor expansion of </b> $e^x$:
# $$ e^x  = \sum_{k=0}^{n}\, \frac{x^k}{k!} + o(x^n) $$

# %% [markdown]
# # Derivatives

# %%
# First order derivative : $$f'(x)$$ 
# K-th order derivative  : $$f^{(k)}(x)$$
# Partial firt order deivative	: $$\frac{\partial f}{\partial x}$$
# Partial k-th order derivative	: $$\frac{\partial^{k} f}{\partial x^k}$$

# %% [markdown]
# [Source](https://gist.githubusercontent.com/ahmedazizkhelifi/89087b2acb38a11671aa2767ea80d15d/raw/3fd79fac0842bbbc231c2bfb8e13e01d21618955/Derivative.tex)

# %% [markdown]
# First order derivative : $$f'(x)$$
# K-th order derivative  : $$f^{(k)}(x)$$
# Partial firt order deivative	: $$\frac{\partial f}{\partial x}$$
# Partial k-th order derivative	: $$\frac{\partial^{k} f}{\partial x^k}$$

# %% [markdown]
# # Insert Youtube Video

# %%
# Use iframe in HTML
# from IPython.display import HTML

# Youtube
#HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/jy0R3V5LRHc" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')

# %%
from IPython.display import HTML

# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/lrEAu75zhNI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/lrEAu75zhNI" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
